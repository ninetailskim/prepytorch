# %%
# !python ./examples/fast_neural_style/neural_style/neural_style.py eval --content-image 2.png --model './gdrive/My Drive/save_model_for_colab/epoch_1_Thu_Mar__7_11:19:45_2019_100000.0_10000000000.0.model' --output-image './gdrive/My Drive/save_model_for_colab/22.jpg' --cuda 1
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
