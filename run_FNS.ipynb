# %%
# !git clone https://github.com/pytorch/examples

# %%
# !git clone https://github.com/fyu/lsun

# %%
# !python ./lsun/download.py -c bedroom

# %%
# !unzip bedroom_train_lmdb.zip

# %%
# !unzip bedroom_val_lmdb.zip

# %%
# !wget http://images.cocodataset.org/zips/train2014.zip

# %%
# !unzip train2014.zip -d data

# %%
# !python ./examples/fast_neural_style/neural_style/neural_style.py train --dataset './data/' --style-image ./examples/fast_neural_style/images/style-images/candy.jpg --save-model-dir './gdrive/My Drive/save_model_for_colab/' --epoch 3 --cuda 1 --checkpoint-model-dir './gdrive/My Drive/save_model_for_colab/'

# %%
# !apt-get install google-drive-ocamlfuse

# %%
# !google-drive-ocamlfuse -cc

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#drive.mount("/content/gdrive", force_remount=True)
with open('/content/gdrive/My Drive/file.txt', 'w') as f:
  f.write('content')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !mkdir data

# %%
# !cp -r train2014 data

# %%
# !pip install lmdb

# %%
# !python examples/dcgan/main.py --dataset lsun --dataroot './' --outf './gdrive1/My Drive/save_model_for_colab/' --cuda --netG './gdrive1/My Drive/save_model_for_colab/netG_epoch_1_0.pth' --netD './gdrive1/My Drive/save_model_for_colab/netD_epoch_1_0.pth'
# Out:
# Mounted at /content/gdrive1
# Namespace(batchSize=256, beta1=0.5, cuda=True, dataroot='./', dataset='lsun', imageSize=64, lr=0.0002, manualSeed=None, ndf=64, netD='./gdrive1/My Drive/save_model_for_colab/netD_epoch_1_0.pth', netG='./gdrive1/My Drive/save_model_for_colab/netG_epoch_1_0.pth', ngf=64, ngpu=1, niter=25, nz=100, outf='./gdrive1/My Drive/save_model_for_colab/', workers=2)
# Random Seed:  1971
# asdasdasdasdas
# lsun
# asdasdasdasdas
# asdasdasdasdas
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
# ...

# %%
--netG './gdrive/My Drive/save_model_for_colab/netG_epoch_1_0.pth' --netD './gdrive/My Drive/save_model_for_colab/netD_epoch_1_0.pth'
