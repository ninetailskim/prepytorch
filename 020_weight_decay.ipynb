# %%
import numpy as no
import torch
from torch import nn
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision.datasets import CIFAR10
from Myutils import train, resnet
from torchvision import transforms as tfs

# %%
def data_tf(x):
    im_aug = tfs.Compose([
        tfs.Resize(96),
        tfs.ToTensor(),
        tfs.Normalize([0.5, 0.5, 0.5],[0.5, 0.5, 0.5])
    ])
    x = im_aug(x)
    return x

train_set = CIFAR10('./data', train=True, transform=data_tf)
test_set = CIFAR10('./data', train=False, transform=data_tf)

train_data = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True, num_workers=4)
test_data = torch.utils.data.DataLoader(test_set, batch_size=128, shuffle=False, num_workers=4)

net = resnet(3, 10)
optimizer = torch.optim.SGD(net.parameters(), lr=1e-1, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()

# %%
train(net, train_data, test_data, 10, optimizer, criterion)
# Out:
# /content/Myutils.py:72: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im = Variable(im.cuda(), volatile=True)
# /content/Myutils.py:73: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   label = Variable(label.cuda(), volatile=True)
# Epoch 0. Train Loss: 1.343920, Train Acc: 0.513307, Valid Loss: 2.148537, Valid Acc: 0.402492, Time 00:01:43
# Epoch 1. Train Loss: 0.856983, Train Acc: 0.700268, Valid Loss: 0.981792, Valid Acc: 0.663074, Time 00:01:51
# Epoch 2. Train Loss: 0.634078, Train Acc: 0.779112, Valid Loss: 1.845328, Valid Acc: 0.486353, Time 00:01:51
# Epoch 3. Train Loss: 0.487883, Train Acc: 0.831362, Valid Loss: 1.112949, Valid Acc: 0.640625, Time 00:01:51
# Epoch 4. Train Loss: 0.369259, Train Acc: 0.873022, Valid Loss: 0.850733, Valid Acc: 0.720629, Time 00:01:51
# Epoch 5. Train Loss: 0.273267, Train Acc: 0.904811, Valid Loss: 0.751452, Valid Acc: 0.771756, Time 00:01:51
# Epoch 6. Train Loss: 0.199606, Train Acc: 0.930886, Valid Loss: 0.945513, Valid Acc: 0.735858, Time 00:01:51
# Epoch 7. Train Loss: 0.152206, Train Acc: 0.946891, Valid Loss: 1.107902, Valid Acc: 0.719640, Time 00:01:51
# Epoch 8. Train Loss: 0.111309, Train Acc: 0.961137, Valid Loss: 1.117514, Valid Acc: 0.749308, Time 00:01:51
# Epoch 9. Train Loss: 0.085941, Train Acc: 0.969769, Valid Loss: 1.481649, Valid Acc: 0.697686, Time 00:01:50
