# %%
# !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 26321, done.
# remote: Total 26321 (delta 0), reused 0 (delta 0), pack-reused 26321
# Receiving objects: 100% (26321/26321), 508.77 MiB | 37.37 MiB/s, done.
# Resolving deltas: 100% (15870/15870), done.
# Checking out files: 100% (2978/2978), done.
