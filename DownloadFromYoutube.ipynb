# %%
# !youtube-dl -f mp4 'https://www.youtube.com/playlist?list=PLDzdzeKX7DWep2KyJwJ-BmYciXTARvZO6'
# Out:
# [youtube:playlist] PLDzdzeKX7DWep2KyJwJ-BmYciXTARvZO6: Downloading webpage
# [download] Downloading playlist: 深度学习与PyTorch教程
# [youtube:playlist] playlist 深度学习与PyTorch教程: Downloading 75 videos
# [download] Downloading video 1 of 75
# [youtube] rDhBcP4ikpA: Downloading webpage
# [youtube] rDhBcP4ikpA: Downloading video info webpage
# [youtube] rDhBcP4ikpA: Downloading MPD manifest
# [download] lesson1-PyTorch介绍-rDhBcP4ikpA.mp4 has already been downloaded
# [download] 100% of 50.04MiB
# [download] Downloading video 2 of 75
# [youtube] eQm6RHyYOjg: Downloading webpage
# [youtube] eQm6RHyYOjg: Downloading video info webpage
# [youtube] eQm6RHyYOjg: Downloading MPD manifest
# [download] lesson2-开发环境准备-eQm6RHyYOjg.mp4 has already been downloaded
# [download] 100% of 43.54MiB
# [download] Downloading video 3 of 75
# [youtube] IZ8mjOGQobE: Downloading webpage
# [youtube] IZ8mjOGQobE: Downloading video info webpage
# [youtube] IZ8mjOGQobE: Downloading MPD manifest
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#drive.mount("/content/gdrive", force_remount=True)
with open('/content/gdrive/My Drive/file.txt', 'w') as f:
  f.write('content')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !youtube-dl -f mp4 -o '/content/gdrive/My Drive/DFY/%(title)s' 'https://www.youtube.com/playlist?list=PLDzdzeKX7DWep2KyJwJ-BmYciXTARvZO6'
# Out:
# [youtube:playlist] PLDzdzeKX7DWep2KyJwJ-BmYciXTARvZO6: Downloading webpage
# [download] Downloading playlist: 深度学习与PyTorch教程
# [youtube:playlist] playlist 深度学习与PyTorch教程: Downloading 75 videos
# [download] Downloading video 1 of 75
# [youtube] rDhBcP4ikpA: Downloading webpage
# [youtube] rDhBcP4ikpA: Downloading video info webpage
# [youtube] rDhBcP4ikpA: Downloading MPD manifest
# [download] Destination: /content/gdrive/My Drive/DFY/lesson1-PyTorch介绍
# [download] 100% of 38.75MiB in 00:04
# [download] Downloading video 2 of 75
# [youtube] eQm6RHyYOjg: Downloading webpage
# [youtube] eQm6RHyYOjg: Downloading video info webpage
# [youtube] eQm6RHyYOjg: Downloading MPD manifest
# [download] Destination: /content/gdrive/My Drive/DFY/lesson2-开发环境准备
# [download] 100% of 44.10MiB in 00:06
# [download] Downloading video 3 of 75
# [youtube] IZ8mjOGQobE: Downloading webpage
# [youtube] IZ8mjOGQobE: Downloading video info webpage
# [youtube] IZ8mjOGQobE: Downloading MPD manifest
# ...
