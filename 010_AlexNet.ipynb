# %%
import torch
from torch import nn
import numpy as np
from torch.autograd import Variable
from torchvision.datasets import CIFAR10
import torch.utils.data

# %%
class AlexNet(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(3,64,5),
            nn.ReLU(True)
        )
        
        self.max_pool1 = nn.MaxPool2d(3,2)
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 64, 5, 1),
            nn.ReLU(True)
        )
        
        self.max_pool2 = nn.MaxPool2d(3,2)
        
        self.fc1 = nn.Sequential(
            nn.Linear(1024, 384),
            nn.ReLU(True)
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(384, 192),
            nn.ReLU(True)
        )
        
        self.fc3 = nn.Linear(192, 10)
        
    def forward(self,x):
        x = self.conv1(x)
        x = self.max_pool1(x)
        x = self.conv2(x)
        x = self.max_pool2(x)
        x = x.view(x.shape[0], -1)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %%
alexnet = AlexNet()

# %%
alexnet
# Out:
# AlexNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (max_pool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace)
#   )
#   (max_pool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Sequential(
#     (0): Linear(in_features=1024, out_features=384, bias=True)
#     (1): ReLU(inplace)
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=384, out_features=192, bias=True)
#     (1): ReLU(inplace)
#   )
#   (fc3): Linear(in_features=192, out_features=10, bias=True)
# )

# %%
input_demo = Variable(torch.zeros(1,3,32,32))
output_demo = alexnet(input_demo)
print(output_demo.shape)
# Out:
# torch.Size([1, 10])

# %%
from Myutils import train as uttrain
from Myutils import WTF
from torchvision import transforms


def data_tf(x):
    x = np.array(x, dtype='float32') / 255
    x = (x - 0.5) / 0.5
    x = x.transpose((2,0,1))
    x = torch.from_numpy(x)
    return x

train_set = CIFAR10(root='./data', train=True, transform=data_tf ,download=True)
train_data = torch.utils.data.DataLoader(dataset = train_set, batch_size=64, shuffle=True)

test_set = CIFAR10(root='./data', train=False, transform=data_tf, download=True)
test_data = torch.utils.data.DataLoader(dataset = test_set, batch_size=128, shuffle=False)

net = AlexNet()
optimizer = torch.optim.SGD(net.parameters(), lr=1e-1)
criterion = nn.CrossEntropyLoss()
print("???")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ???

# %%
WTF()
# Out:
# test Fuck!

# %%
uttrain(net, train_data, test_data, 20, optimizer, criterion)
# Out:
# /content/Myutils.py:70: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im = Variable(im.cuda(), volatile=True)
# /content/Myutils.py:71: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   label = Variable(label.cuda(), volatile=True)
# Epoch 0. Train Loss: 1.723855, Train Acc: 0.364310, Valid Loss: 1.763314, Valid Acc: 0.413568, Time 00:00:12
# Epoch 1. Train Loss: 1.265669, Train Acc: 0.547934, Valid Loss: 1.467163, Valid Acc: 0.507120, Time 00:00:14
# Epoch 2. Train Loss: 1.031779, Train Acc: 0.637908, Valid Loss: 1.381448, Valid Acc: 0.534909, Time 00:00:14
# Epoch 3. Train Loss: 0.879607, Train Acc: 0.691596, Valid Loss: 0.984140, Valid Acc: 0.661986, Time 00:00:14
# Epoch 4. Train Loss: 0.763139, Train Acc: 0.733915, Valid Loss: 1.114514, Valid Acc: 0.643295, Time 00:00:14
# Epoch 5. Train Loss: 0.669270, Train Acc: 0.766184, Valid Loss: 0.875422, Valid Acc: 0.711432, Time 00:00:14
# ...

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2019-03-01 03:28:11--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.204.136.9, 52.200.123.104, 52.202.60.111, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.204.136.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5363700 (5.1M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]   5.11M  3.45MB/s    in 1.5s
#
# 2019-03-01 03:28:14 (3.45 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [5363700/5363700]

# %%
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
LOG_DIR = './log'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://35b2e23f.ngrok.io
